# %%
import pandas as pd
import numpy as np

# %%
header = r'./data/description.txt' 
with open(header,'r') as file: headerVal = file.read().split()
filename = r'./data/dataset.txt'

df = pd.read_csv(filename, sep=r'\s*(?:\||\#|\,)\s*', names=headerVal, na_values="?", engine='python')
df
# Out:
#        id,  latitude,  longitude,  stars,         type,    specialty,  price,  \
# 0      TR1  53.337200   -6.265900     4.6  "restaurant"   "hamburger"   "mid"
# 1      TR2  53.431400   -6.199900     4.0  "restaurant"   "hamburger"  "high"
# 2      TR3  53.320400   -6.236000     3.0        "cafe"   "hamburger"   "mid"
# 3      TR4  53.336985   -6.265330     3.6  "restaurant"   "hamburger"   "low"
# 4      TR5  53.337508   -6.266823     3.0        "cafe"   "hamburger"   "mid"
# 5      TR6  53.337498   -6.259800     4.5  "restaurant"   "hamburger"   "mid"
# 6      TR7  53.338293   -6.261070     4.0        "cafe"   "hamburger"   "mid"
# 7      TR8  53.349280   -6.210850     4.0  "restaurant"      "casual"  "high"
# 8      TR9  53.337247   -6.261540     4.2  "restaurant"      "casual"   "mid"
# 9     TR10  53.335481   -6.266304     3.8  "restaurant"      "casual"   "low"
# 10    TR11  53.331764   -6.250350     4.6  "restaurant"   "hamburger"   "mid"
# ...
